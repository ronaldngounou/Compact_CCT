# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_json("C:\Education\MSCS UDC\Research Projects\CCT Project\datasets\Ammonium ACTSOR-AQUA-UDC-1 2017-01-26T01%3A01&to=2017-01-26T12%3A59.json")

# %%
df.head()
# Out:
#             ballName       readTime  ammonium
# 0  ACTSOR-AQUA-UDC-1  1485421966960       4.8
# 1  ACTSOR-AQUA-UDC-1  1485421972020       4.8
# 2  ACTSOR-AQUA-UDC-1  1485421977191       4.9
# 3  ACTSOR-AQUA-UDC-1  1485421982350       4.8
# 4  ACTSOR-AQUA-UDC-1  1485421987433       4.8

# %%
df.plot(x="readTime", y="ammonium")
# Out:
# <Axes: xlabel='readTime'>
